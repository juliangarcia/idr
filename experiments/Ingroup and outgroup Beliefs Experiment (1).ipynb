# %%
import model
import numpy as np;
import matplotlib.pyplot as plt;

# %%
def mc_experiment(game_name, monte_carlo_steps, number_of_agents, R, S, T, P, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale):
    
    payoffs = np.zeros(number_of_steps, dtype=float)
    payoffs_tag0 = np.zeros(number_of_steps, dtype=float) 
    payoffs_tag1 =np.zeros(number_of_steps, dtype=float)
    ingroup = np.zeros(number_of_steps, dtype=float)
    ingroup_tag0 = np.zeros(number_of_steps, dtype=float)
    ingroup_tag1 = np.zeros(number_of_steps, dtype=float)
    outgroup = np.zeros(number_of_steps, dtype=float)
    outgroup_tag0 = np.zeros(number_of_steps, dtype=float)
    outgroup_tag1 = np.zeros(number_of_steps, dtype=float)
    
    a_model = model.Model(number_of_agents, R, S, T, P, tag0_in, tag0_out, tag1_in, tag1_out, number_of_tag0_agents)
    
    for m in range(monte_carlo_steps):
        returned_array = a_model.run_monte_carlo_simulation(0, number_of_steps, rounds_per_step,
                       selection_intensity, perturbation_probability, perturbation_scale, "false", " ", " ", "")
        
        payoffs += returned_array[0]
        payoffs_tag0 += returned_array[1]
        payoffs_tag1 += returned_array[2]
        ingroup += returned_array[3]
        ingroup_tag0 += returned_array[4]
        ingroup_tag1 += returned_array[5]
        outgroup += returned_array[6]
        outgroup_tag0 += returned_array[7]
        outgroup_tag1 += returned_array[8]
        
        print("Experiment ", m)
    
    payoffs = payoffs/ monte_carlo_steps
    payoffs_tag0 = payoffs_tag0/monte_carlo_steps
    payoffs_tag1 = payoffs_tag1/ monte_carlo_steps
    ingroup = ingroup/ monte_carlo_steps
    ingroup_tag0 = ingroup_tag0/ monte_carlo_steps
    ingroup_tag1 = ingroup_tag1/ monte_carlo_steps
    outgroup = outgroup/ monte_carlo_steps
    outgroup_tag0 = outgroup_tag0/monte_carlo_steps
    outgroup_tag1 = outgroup_tag1/monte_carlo_steps
    
    plt.plot(ingroup, label="Average total ingroup")
    plt.plot(ingroup_tag0, label="Average tag 0 ingroup")
    plt.plot(ingroup_tag1, label="Average tag 1 ingroup")
    plt.legend()
    plt.title("{}: Ingroup Belief".format(game_name) )
    plt.show()
    
    plt.plot(outgroup, label="Average total outgroup")
    plt.plot(outgroup_tag0, label="Average tag 0 outgroup")
    plt.plot(outgroup_tag1, label="Average tag 1 outgroup")
    plt.legend()
    plt.title("{}: Outgroup Belief".format(game_name) )
    plt.show()

# %%
# Parameters

monte_carlo_steps = 10
number_of_agents = 10 
tag0_in = 1
tag0_out = 0
tag1_in = 1
tag1_out = 0
number_of_tag0_agents = 5
number_of_steps = 1000
rounds_per_step =100
selection_intensity = 0.1
perturbation_probability = 0.05 
perturbation_scale = 0.05 

# PD =  [-1, -3, 0, -2]
# SH = [4, 1, 3, 2]

# %%
# Experimenting with the number of monte carlo repeations 
monte_carlo_steps = 10

# PD game
mc_experiment("PD", monte_carlo_steps, number_of_agents, -1, -3, 0, -2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# SH game
mc_experiment("SH", monte_carlo_steps, number_of_agents, 4, 1, 3, 2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)
# Out:
# Experiment  0
# Experiment  1
# Experiment  2
# Experiment  3
# Experiment  4
# Experiment  5
# Experiment  6
# Experiment  7
# Experiment  8
# Experiment  9
# Experiment  0
# Experiment  1
# Experiment  2
# Experiment  3
# Experiment  4
# Experiment  5
# Experiment  6
# Experiment  7
# Experiment  8
# Experiment  9

# %%
# Experimenting with changing the number of monte carlo steps 
monte_carlo_steps = 50

# PD game
mc_experiment("PD", monte_carlo_steps, number_of_agents, -1, -3, 0, -2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# SH game
mc_experiment("SH", monte_carlo_steps, number_of_agents, 4, 1, 3, 2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)
# Out:
# Experiment  0
# Experiment  1
# Experiment  2
# Experiment  3
# Experiment  4
# Experiment  5
# Experiment  6
# Experiment  7
# Experiment  8
# Experiment  9
# Experiment  10
# Experiment  11
# Experiment  12
# Experiment  13
# Experiment  14
# Experiment  15
# Experiment  16
# Experiment  17
# Experiment  18
# Experiment  19
# Experiment  20
# Experiment  21
# Experiment  22
# Experiment  23
# Experiment  24
# Experiment  25
# Experiment  26
# Experiment  27
# Experiment  28
# Experiment  29
# Experiment  30
# Experiment  31
# Experiment  32
# Experiment  33
# Experiment  34
# Experiment  35
# Experiment  36
# Experiment  37
# Experiment  38
# Experiment  39
# Experiment  40
# Experiment  41
# Experiment  42
# Experiment  43
# Experiment  44
# Experiment  45
# Experiment  46
# Experiment  47
# Experiment  48
# Experiment  49
# Experiment  0
# Experiment  1
# Experiment  2
# Experiment  3
# Experiment  4
# Experiment  5
# Experiment  6
# Experiment  7
# Experiment  8
# Experiment  9
# ...

# %%
# Experimenting with number of monte carlo experiemtns 
monte_carlo_steps = 100

# PD game
mc_experiment("PD", monte_carlo_steps, number_of_agents, -1, -3, 0, -2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# SH game
mc_experiment("SH", monte_carlo_steps, number_of_agents, 4, 1, 3, 2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# %% [markdown]
# Sadly, inconsistent and non-convergent results were achieved. The average ingroup/outgroup belief of all agents was roughly 0.5 for all of them however the belifs of the tag groups widly changed and neither group consistently achieved stronger results as the number of included experiments increased.

# %%
# Experimenting with increasing selection intensity and number of steps in the simulation to see if we can
# achieve some kind of consistency/convergence 
monte_carlo_steps = 10
selection_intensity = 2.0 
number_of_steps = 2000

# PD game
mc_experiment("PD", monte_carlo_steps, number_of_agents, -1, -3, 0, -2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# SH game
mc_experiment("SH", monte_carlo_steps, number_of_agents, 4, 1, 3, 2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# %%
# Milder selection intensity
monte_carlo_steps = 10
selection_intensity = 0.5 
number_of_steps = 1000

# PD game
mc_experiment("PD", monte_carlo_steps, number_of_agents, -1, -3, 0, -2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# SH game
mc_experiment("SH", monte_carlo_steps, number_of_agents, 4, 1, 3, 2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# %%
# increase perturbation probability, so agents are more likely to change belief so might converge quicker 
monte_carlo_steps = 10
selection_intensity = 0.5 
number_of_steps = 2000
perturbation_probability = 0.1 

# PD game
mc_experiment("PD", monte_carlo_steps, number_of_agents, -1, -3, 0, -2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# SH game
mc_experiment("SH", monte_carlo_steps, number_of_agents, 4, 1, 3, 2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# %%
# increase number of steps again  
monte_carlo_steps = 10
selection_intensity = 0.5 
number_of_steps = 3000
perturbation_probability = 0.1 

# PD game
mc_experiment("PD", monte_carlo_steps, number_of_agents, -1, -3, 0, -2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# SH game
mc_experiment("SH", monte_carlo_steps, number_of_agents, 4, 1, 3, 2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# %%
# Trying the exact same parameters as Matthew's final payoff experiment only difference is perturbation_probability 
# is 0.05 not 0.1
monte_carlo_steps = 10
selection_intensity = 0.5 
number_of_steps = 3000
perturbation_probability = 0.05 

# PD game
mc_experiment("PD", monte_carlo_steps, number_of_agents, -1, -3, 0, -2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# SH game
mc_experiment("SH", monte_carlo_steps, number_of_agents, 4, 1, 3, 2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)
# Out:
# Experiment  0
# Experiment  1
# Experiment  2
# Experiment  3
# Experiment  4
# Experiment  5
# Experiment  6
# Experiment  7
# Experiment  8
# Experiment  9
# Experiment  0
# Experiment  1
# Experiment  2
# Experiment  3
# Experiment  4
# Experiment  5
# Experiment  6
# Experiment  7
# Experiment  8
# Experiment  9

# %%
# Experimenting with changing the initial beliefs 
monte_carlo_steps = 10
selection_intensity = 0.5 
number_of_steps = 3000
perturbation_probability = 0.1 
tag0_in = 0.8
tag0_out = 0.3
tag1_in = 0.8
tag1_out = 0.3

# PD game
mc_experiment("PD", monte_carlo_steps, number_of_agents, -1, -3, 0, -2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# SH game
mc_experiment("SH", monte_carlo_steps, number_of_agents, 4, 1, 3, 2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)
# Out:
# Experiment  0
# Experiment  1
# Experiment  2
# Experiment  3
# Experiment  4
# Experiment  5
# Experiment  6
# Experiment  7
# Experiment  8
# Experiment  9
# Experiment  0
# Experiment  1
# Experiment  2
# Experiment  3
# Experiment  4
# Experiment  5
# Experiment  6
# Experiment  7
# Experiment  8
# Experiment  9

# %%
# Experimenting with changing the initial beliefs 
tag0_in = 0.5
tag0_out = 0.5
tag1_in = 0.5
tag1_out = 0.5

# PD game
mc_experiment("PD", monte_carlo_steps, number_of_agents, -1, -3, 0, -2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)

# SH game
mc_experiment("SH", monte_carlo_steps, number_of_agents, 4, 1, 3, 2, tag0_in, tag0_out, tag1_in, tag1_out, 
                  number_of_tag0_agents, number_of_steps, rounds_per_step, selection_intensity, 
                  perturbation_probability, perturbation_scale)
# Out:
# Experiment  0
# Experiment  1
# Experiment  2
# Experiment  3
# Experiment  4
# Experiment  5
# Experiment  6
# Experiment  7
# Experiment  8
# Experiment  9
# Experiment  0
# Experiment  1
# Experiment  2
# Experiment  3
# Experiment  4
# Experiment  5
# Experiment  6
# Experiment  7
# Experiment  8
# Experiment  9
